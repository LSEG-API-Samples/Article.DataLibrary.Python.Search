# %% [markdown]
# ## Query
# The most basic search that can be performed is the query.  The query is a free-formed text expression, similar to the type of query you can perform within Google, matching against documents within the specified view.

# %%
import refinitiv.data as rd
from refinitiv.data.content import search
import pandas as pd

# Default session - desktop
rd.open_session()
# Out:
# <refinitiv.data.session.Definition object at 0x240a19f00d0 {name='default'}>

# %%
pd.set_option('display.max_colwidth', 140)
rd.__version__
# Out:
# '1.0.0b9'

# %% [markdown]
# #### Query - Default behavior

# %%
# The default syntax for search is to specify a query expression.  By default, search will return a default set of 
# fields (Properties).
response=search.Definition('IBM').get_data()
response.data.df
# Out:
#   BusinessEntity  \
# 0   ORGANISATION
# 1   ORGANISATION
# 2   QUOTExEQUITY
# 3   ORGANISATION
# 4   QUOTExEQUITY
# 5   QUOTExEQUITY
# 6   QUOTExEQUITY
# 7   QUOTExEQUITY
# 8   QUOTExEQUITY
# 9   QUOTExEQUITY
#
#                                                                                                 DocumentTitle  \
# 0                                                        International Business Machines Corp, Public Company
# 1                                                                               Banco IBM SA, Private Company
# 2                                     International Business Machines Corp, Ordinary Share, NYSE Consolidated
# 3                           Tiers Corporate Bond Backed Certificates Trust Series Ibm 1997 4, Private Company
# 4              Eurex International Business Machines Equity Future Chain Contract , Equity Future, USD, Eurex
# 5              Euronext Amsterdam IBM Dividend Future Chain Contracts, Equity Future, USD, Euronext Amsterdam
# 6               Eurex International Business Machines Equity Future Continuation 1, Equity Future, USD, Eurex
# 7               Eurex International Business Machines Equity Future Continuation 2, Equity Future, USD, Eurex
# 8  Euronext Amsterdam IBM Single Stock Dividend Future Continuation 1, Equity Future, USD, Euronext Amsterdam
# 9               Eurex International Business Machines Equity Future Continuation 3, Equity Future, USD, Eurex
#
#         PermID         PI       RIC
# 0         <NA>      37036      <NA>
# 1         <NA>      76208      <NA>
# 2  55839165994    1097326       IBM
# 3         <NA>   18062670      <NA>
# 4  21481052421   48924732   0#IBMF:
# 5  21612423771  259118763  0#IBMDF:
# 6  21481052892   49450681    IBMFc1
# 7  21481053949   50092347    IBMFc2
# 8  21613372305  260213021   IBMDFc1
# 9  21481053950   50092348    IBMFc3

# %%
# By default, 10 documents will be returned.  Let's override that.
response=search.Definition(
    query = 'IBM',
    top = 20
).get_data()
response.data.df
# Out:
#    BusinessEntity  \
# 0    ORGANISATION
# 1    ORGANISATION
# 2    QUOTExEQUITY
# 3    ORGANISATION
# 4    QUOTExEQUITY
# 5    QUOTExEQUITY
# 6    QUOTExEQUITY
# 7    QUOTExEQUITY
# 8    QUOTExEQUITY
# 9    QUOTExEQUITY
# 10   QUOTExEQUITY
# 11   QUOTExEQUITY
# 12   QUOTExEQUITY
# 13   QUOTExEQUITY
# 14   QUOTExEQUITY
# 15   QUOTExEQUITY
# 16   QUOTExEQUITY
# 17   QUOTExEQUITY
# 18   QUOTExEQUITY
# 19   QUOTExEQUITY
#
#                                                                                                  DocumentTitle  \
# 0                                                         International Business Machines Corp, Public Company
# 1                                                                                Banco IBM SA, Private Company
# 2                                      International Business Machines Corp, Ordinary Share, NYSE Consolidated
# 3                            Tiers Corporate Bond Backed Certificates Trust Series Ibm 1997 4, Private Company
# 4               Eurex International Business Machines Equity Future Chain Contract , Equity Future, USD, Eurex
# 5               Euronext Amsterdam IBM Dividend Future Chain Contracts, Equity Future, USD, Euronext Amsterdam
# 6                Eurex International Business Machines Equity Future Continuation 1, Equity Future, USD, Eurex
# 7                Eurex International Business Machines Equity Future Continuation 2, Equity Future, USD, Eurex
# 8   Euronext Amsterdam IBM Single Stock Dividend Future Continuation 1, Equity Future, USD, Euronext Amsterdam
# 9                Eurex International Business Machines Equity Future Continuation 3, Equity Future, USD, Eurex
# 10               Eurex International Business Machines Equity Future Continuation 4, Equity Future, USD, Eurex
# 11  Euronext Amsterdam IBM Single Stock Dividend Future Continuation 2, Equity Future, USD, Euronext Amsterdam
# 12               Eurex International Business Machines Equity Future Continuation 5, Equity Future, USD, Eurex
# 13               Eurex International Business Machines Equity Future Continuation 6, Equity Future, USD, Eurex
# 14  Euronext Amsterdam IBM Single Stock Dividend Future Continuation 3, Equity Future, USD, Euronext Amsterdam
# 15               Eurex International Business Machines Equity Future Continuation 7, Equity Future, USD, Eurex
# 16               Eurex International Business Machines Equity Future Continuation 8, Equity Future, USD, Eurex
# 17  Euronext Amsterdam IBM Single Stock Dividend Future Continuation 4, Equity Future, USD, Euronext Amsterdam
# 18               Eurex International Business Machines Equity Future Continuation 9, Equity Future, USD, Eurex
# 19              Eurex International Business Machines Equity Future Continuation 10, Equity Future, USD, Eurex
#
#          PermID         PI       RIC
# 0          <NA>      37036      <NA>
# 1          <NA>      76208      <NA>
# 2   55839165994    1097326       IBM
# 3          <NA>   18062670      <NA>
# 4   21481052421   48924732   0#IBMF:
# 5   21612423771  259118763  0#IBMDF:
# 6   21481052892   49450681    IBMFc1
# 7   21481053949   50092347    IBMFc2
# 8   21613372305  260213021   IBMDFc1
# 9   21481053950   50092348    IBMFc3
# 10  21481053951   50092349    IBMFc4
# 11  21613372306  260213022   IBMDFc2
# 12  21481053952   50092350    IBMFc5
# 13  21481053953   50092351    IBMFc6
# 14  21613372307  260213023   IBMDFc3
# 15  21481053954   50092352    IBMFc7
# 16  21481053955   50092353    IBMFc8
# 17  21613372308  260213024   IBMDFc4
# 18  21481053956   50092354    IBMFc9
# 19  21481053957   50092355   IBMFc10

# %% [markdown]
# #### Query Expressions
# If we were to type in the following expression, we might come away believing the query will list all personnel within IBM that have a title
# of CEO.  While, the results will indicate people related to IBM and people with a title of CEO, we cannot assume they are both.  That is,
# we will see results with the term IBM and CEO listed in the document.

# %%
# Match all documents where the term IBM and CEO appear in any order
response=search.Definition('IBM CEO').get_data()
response.data.df
# Out:
#   BusinessEntity  \
# 0         PERSON
# 1         PERSON
# 2         PERSON
# 3         PERSON
# 4         PERSON
# 5         PERSON
# 6         PERSON
# 7         PERSON
# 8         PERSON
#
#                                                                                             DocumentTitle  \
# 0  Arvind Krishna - International Business Machines Corp - Chairman of the Board, Chief Executive Officer
# 1                           Rudy S. Karsan - Kenexa Corp - Chairman of the Board, Chief Executive Officer
# 2            Mohammed Farooq - Gravitant Inc - Chairman of the Board, Chief Executive Officer, Co-Founder
# 3          Simon J. Beaumont - IBM Credit LLC - Chairman of the Board, President, Chief Executive Officer
# 4                                          Deidre Paknad - Pss Systems Inc - President, CEO, Board Member
# 5                                                        Ron S Dembo - Algorithmics Inc - President & CEO
# 6                                                           Frank Chisholm - Aptsoft Corp - CEO & Founder
# 7                                  Michael Knagenhjelm - Metamerge As(Ibm Corp) - Chief Executive Officer
# 8                                           Bruce Miller - Tarian Software(Ibm) - Chief Executive Officer
#
#         PermID           PI
# 0  34417810693  34417810693
# 1  34413248256  34413248256
# 2  34415058863  34415058863
# 3  34421596181  34421596181
# 4  34414057544  34414057544
# 5  34414091235  34414091235
# 6  34414058841  34414058841
# 7  34414139687  34414139687
# 8  34414399995  34414399995

# %% [markdown]
# What might give a more favorable result would be to query all documents related to people that contain the term '*IBM*'. From the result, I can visually see
# titles and optionally filter out people that are not CEO's.  I can do this by selecting the '**People**' view.
# In addition, I'm going to choose specific *child* elements of the **DocumentTitle** field.  As we see in our output from the above requests, the
# '**DocumentTitle**' is selected by default.  This property is a convenient collection of elements that nicely describes the document returned and is
# made up of multiple sub-properties such as: '**DTSubjectName**', '**DTSimpleType**', '**DTSource**', and '**DTCharacteristics**'.
#
# By doing this, I can now see a nice
# break-down of the titles (DTCharacteristics), name (DTSubjectName) and company (DTSimpleType).

# %%
response=search.Definition(
    view = search.SearchViews.PEOPLE,
    query = 'IBM',
    select = 'DocumentTitle, DTSubjectName, DTSimpleType, DTSource, DTCharacteristics'
).get_data()
response.data.df
# Out:
#                                                                                                                 DocumentTitle  \
# 0                      Arvind Krishna - International Business Machines Corp - Chairman of the Board, Chief Executive Officer
# 1                                                         Gary D. Cohn - International Business Machines Corp - Vice Chairman
# 2                  James J. Kavanaugh - International Business Machines Corp - Senior Vice President, Chief Financial Officer
# 3               Nickle LaMoreaux - International Business Machines Corp - Chief Human Resource Officer, Senior Vice President
# 4  Thomas W. Rosamilia - International Business Machines Corp - Senior Vice President - IBM Software, Chairman, North America
# 5                       Michelle H. Browdy - International Business Machines Corp - Senior Vice President and General Counsel
# 6                                      Robert F. Del Bene - International Business Machines Corp - Vice President, Controller
# 7                                                 David N. Farr - International Business Machines Corp - Independent Director
# 8                                                  Al W. Zollar - International Business Machines Corp - Independent Director
# 9                                               Rick H. Waddell - International Business Machines Corp - Independent Director
#
#          DTSubjectName                          DTSimpleType  \
# 0       Arvind Krishna  International Business Machines Corp
# 1         Gary D. Cohn  International Business Machines Corp
# 2   James J. Kavanaugh  International Business Machines Corp
# 3     Nickle LaMoreaux  International Business Machines Corp
# 4  Thomas W. Rosamilia  International Business Machines Corp
# 5   Michelle H. Browdy  International Business Machines Corp
# 6   Robert F. Del Bene  International Business Machines Corp
# 7        David N. Farr  International Business Machines Corp
# 8         Al W. Zollar  International Business Machines Corp
# 9      Rick H. Waddell  International Business Machines Corp
#
#                                                DTCharacteristics
# 0                 Chairman of the Board, Chief Executive Officer
# 1                                                  Vice Chairman
# 2                 Senior Vice President, Chief Financial Officer
# 3            Chief Human Resource Officer, Senior Vice President
# 4  Senior Vice President - IBM Software, Chairman, North America
# 5                      Senior Vice President and General Counsel
# 6                                     Vice President, Controller
# 7                                           Independent Director
# 8                                           Independent Director
# 9                                           Independent Director

# %%
# Search for a specific ISIN using query
response=search.Definition('US046353AQ14').get_data()
response.data.df
# Out:
#                    BusinessEntity  \
# 0  INSTRUMENTxFIXEDINCOMExGOVCORP
# 1       QUOTExFIXEDINCOMExGOVCORP
# 2       QUOTExFIXEDINCOMExGOVCORP
# 3       QUOTExFIXEDINCOMExGOVCORP
# 4       QUOTExFIXEDINCOMExGOVCORP
# 5       QUOTExFIXEDINCOMExGOVCORP
# 6       QUOTExFIXEDINCOMExGOVCORP
# 7       QUOTExFIXEDINCOMExGOVCORP
# 8       QUOTExFIXEDINCOMExGOVCORP
# 9       QUOTExFIXEDINCOMExGOVCORP
#
#                                                                                      DocumentTitle  \
# 0           AstraZeneca PLC, Plain Vanilla Fixed Coupon Bond, TRACE Eligible AZN 2.375 12-Jun-2022
# 1                   AstraZeneca PLC, Bond Quote, TRACE Eligible AZN 2.375 12-Jun-2022, MARKETAXESS
# 2                AstraZeneca PLC, Bond Quote, TRACE Eligible AZN 2.375 12-Jun-2022, MARKETAXESS L2
# 3       AstraZeneca PLC, Bond Quote, TRACE Eligible AZN 2.375 12-Jun-2022, BARCLAYS TRADEWEB PRICE
# 4  AstraZeneca PLC, Bond Quote, TRACE Eligible AZN 2.375 12-Jun-2022, CREDIT SUISSE TRADEWEB PRICE
# 5           AstraZeneca PLC, Bond Quote, TRACE Eligible AZN 2.375 12-Jun-2022, HSBC TRADEWEB PRICE
# 6    AstraZeneca PLC, Bond Quote, TRACE Eligible AZN 2.375 12-Jun-2022, MARKETAXESS COMPOSITE PLUS
# 7            AstraZeneca PLC, Bond Quote, TRACE Eligible AZN 2.375 12-Jun-2022, RBC TRADEWEB PRICE
# 8                  AstraZeneca PLC, Bond Quote, TRACE Eligible AZN 2.375 12-Jun-2022, TRADEWEB APA
# 9            AstraZeneca PLC, Bond Quote, TRACE Eligible AZN 2.375 12-Jun-2022, TDS TRADEWEB PRICE
#
#         PermID                  PI                RIC
# 0  46645702869  0x00102cb50fde0d55         046353AQ1=
# 1         <NA>  0x00102c2380de0d4c       046353AQ1=1M
# 2         <NA>  0x00102c9a7ade0d0f       046353AQ1=2M
# 3         <NA>  0x00102cbda5d029dd  US046353AQ14=BXTW
# 4         <NA>  0x00102cbda5b71586  US046353AQ14=CSTW
# 5         <NA>  0x00102c506eee30dc  US046353AQ14=HSTW
# 6         <NA>  0x00102ce0bcbf19c6  US046353AQ14=MKCP
# 7         <NA>  0x00102cb583d42ff1  US046353AQ14=RCTW
# 8         <NA>  0x00102ce830f8273b  US046353AQ14=TBEA
# 9         <NA>  0x00102c435ce30dcd  US046353AQ14=TDTW

# %%
# Narrow the search to only instruments
response=search.Definition(
    view = search.SearchViews.INSTRUMENTS,
    query = 'US046353AQ14'
).get_data()
response.data.df
# Out:
#                    BusinessEntity  \
# 0  INSTRUMENTxFIXEDINCOMExGOVCORP
#
#                                                                             DocumentTitle  \
# 0  AstraZeneca PLC, Plain Vanilla Fixed Coupon Bond, TRACE Eligible AZN 2.375 12-Jun-2022
#
#         PermID                  PI         RIC
# 0  46645702869  0x00102cb50fde0d55  046353AQ1=

# %% [markdown]
# #### Query Syntax
# A query phrase can support some basic syntax including wildcards, boolean expressions and exact phrase matching.

# %%
# Use a specifc term in quotes and the boolean operator to locate specific tankers - use the Content layer 
# to print additional details.
response = search.Definition("'Caribbean Tanker' and Baltic").get_data()
print(f'Matched a total of {response.total} documents')
response.data.df
# Out:
# Matched a total of 19 documents
#          BusinessEntity  \
# 0       QUOTExCOMMODITY
# 1       QUOTExCOMMODITY
# 2       QUOTExCOMMODITY
# 3       QUOTExCOMMODITY
# 4  PHYSICALASSETxVESSEL
# 5  PHYSICALASSETxVESSEL
# 6  PHYSICALASSETxVESSEL
# 7  PHYSICALASSETxVESSEL
# 8  PHYSICALASSETxVESSEL
# 9  PHYSICALASSETxVESSEL
#
#                                                                                                                       DocumentTitle  \
# 0                                                                 Baltic Exchange TD9 CRB-USG, Commodity Index, The Baltic Exchange
# 1                   Baltic Exchange Dirty Tanker TD21 Caribbean to US Gulf (50,000mt fuel oil), Commodity Spot, The Baltic Exchange
# 2                       Baltic Exchange Dirty Tanker TD9 TCE�Caribbean to US Gulf Time Charter, Commodity Spot, The Baltic Exchange
# 3  Baltic Exchange Dirty Tanker TD21 TCE Caribbean to US Gulf (50,000mt fuel oil) Time Charter, Commodity Spot, The Baltic Exchange
# 4                                                 SAO PAULO, VLCC, MED & BALTIC SHIPMANAGEMENT, Caribbean Sea|Caribbean Tanker Zone
# 5                                                     NS BORA, Suezmax, SCF MANAGEMENT SERVICES LTD, West Atlantic Ocean (Americas)
# 6                                       PANTHER I, Aframax / LRII, WATERSIDE INTERNATIONAL MTME, Gulf of Finland|Baltic Tanker Zone
# 7                                                   HONG KONG DAWN, Aframax / LRII, HEIDMAR INC, Gulf of Mexico|US Gulf Tanker Zone
# 8                                                 THYA, Aframax / LRII, WINOCEAN MANAGEMENT LTD, Gulf of Finland|Baltic Tanker Zone
# 9                  TAMIAT NAVIGATOR, Medium, IINO MARINE SERVICE CO LTD, Louisiana|Gulf of Mexico|US Gulf Tanker Zone|United States
#
#         PermID           PI             RIC
# 0  21815646948       621981           .BACG
# 1  21717867959    175653765           .BACR
# 2  21717782063     48950908       .BAAFRTD9
# 3  21717782060    325658314      .BAAFRTD21
# 4  77309483963  77309483963  C}KV7309483963
# 5  77309497298  77309497298  C}KS7309497298
# 6  77309487041  77309487041  C}KA7309487041
# 7  77309496423  77309496423  C}KA7309496423
# 8  77309486290  77309486290  C}KA7309486290
# 9  77309498150  77309498150  C}KM7309498150

# %%
# Use a wildcard (*) to search for references to 'Covid*'.
response=search.Definition(
    query = "Covid*",
    select = "DTSubjectName, DTSimpleType, DTSource, DTCharacteristics"
).get_data()
print(f'Matched a total of {response.total} documents')
response.data.df
# Out:
# Matched a total of 9509 documents
#                                                                           DTSubjectName  \
# 0                                                               Covidh Technologies Ltd
# 1                                Euro Zone, Coronavirus (COVID-19), Total cases, Volume
# 2                                  Euro Zone, Coronavirus (COVID-19), New cases, Volume
# 3                                     Euro Zone, Coronavirus (COVID-19), Deaths, Volume
# 4                                           Coronavirus (COVID-19), Total cases, Volume
# 5  Coronavirus (COVID-19), Vaccinations, Doses administered, Per hundred people, Volume
# 6                   Coronavirus (COVID-19), Vaccinations, People vaccinated, % of total
# 7               Coronavirus (COVID-19), Vaccinations, Doses administered, Total, Volume
# 8                                             Coronavirus (COVID-19), New cases, Volume
# 9             Coronavirus (COVID-19), Vaccinations, People fully vaccinated, % of total
#
#      DTSimpleType           DTSource DTCharacteristics
# 0  Public Company               <NA>              <NA>
# 1   Reuters Polls            Reuters             Daily
# 2   Reuters Polls            Reuters             Daily
# 3   Reuters Polls            Reuters             Daily
# 4   Reuters Polls            Reuters             Daily
# 5   Reuters Polls  Our World in Data             Daily
# 6   Reuters Polls  Our World in Data             Daily
# 7   Reuters Polls  Our World in Data             Daily
# 8   Reuters Polls            Reuters             Daily
# 9   Reuters Polls  Our World in Data             Daily

# %%
# List the Vodafone bonds maturing in 2025 with a coupon rate of 5%
# We can achieve this specific query using a special feature called 'tcm' (ticker coupon maturity).
response=search.Definition(
    query = "vod 5% 2025",
    features = "tcm",
    select = "CouponCurrency, CouponTypeDescription, IssuerLegalName, CouponRate, MaturityDate, ISIN"
).get_data()
response.data.df
# Out:
#   CouponCurrency             CouponTypeDescription  \
# 0            USD  Fixed:Plain Vanilla Fixed Coupon
# 1            USD  Fixed:Plain Vanilla Fixed Coupon
#
#                  IssuerLegalName  CouponRate              MaturityDate  \
# 0  Vodafone Hessen GmbH & Co. KG           5  2025-01-15T00:00:00.000Z
# 1  Vodafone Hessen GmbH & Co. KG           5  2025-01-15T00:00:00.000Z
#
#            ISIN
# 0  USD85455AD13
# 1  US913364AD74

# %%
rd.close_session()
